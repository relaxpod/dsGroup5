# %% [markdown]
# <a href="https://colab.research.google.com/github/relaxpod/dsGroup5/blob/main/DSTC_Visuals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
url = "https://raw.githubusercontent.com/relaxpod/dsGroup5/refs/heads/main/states_insurance_dataset_regions.csv"
df = pd.read_csv(url)
df
# Out:
#   US Regions  Uninsured Rate (2015) Average  \
# 0       West                       0.098308
# 1      South                       0.111357
# 2    Midwest                       0.074667
# 3  Northeast                       0.059636
#
#    Average Monthly Tax Credit (2016)  \
# 0                             312.69
# 1                             313.07
# 2                             270.67
# 3                             261.27
#
#    Employer Health Insurance Coverage (2015) Percentage  \
# 0                                           0.523572
# 1                                           0.497540
# 2                                           0.579352
# 3                                           0.585284
#
#    Medicaid Enrollment (2016) Percentage
# 0                               0.225732
# 1                               0.220678
# 2                               0.184631
# 3                               0.244918

# %%
df2 =

# %%
# Table for Uninsured Rate by Region
feature_importances = pd.DataFrame({
    "US Regions": X.columns,
    "Importance": dt_model.feature_importances_
}).sort_values(by="Importance", ascending=False)
print("\nDecision Tree Feature Importances:\n")
feature_importances
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-8cebedec266c> in <cell line: 2>()
#       1 # Table for Uninsured Rate by Region
#       2 feature_importances = pd.DataFrame({
# ----> 3     "US Regions": X.columns,
#       4     "Importance": dt_model.feature_importances_
#       5 }).sort_values(by="Importance", ascending=False)
#
# NameError: name 'X' is not defined

# %%
# Bar Plot for Uninsured Rate
plt.figure(figsize=(8, 5))
plt.barh(df["US Regions"], df["Uninsured Rate (2015) Average"], color="skyblue")
plt.xlabel("Uninsured Rate")
plt.title("The Average Uninsured Rate for Each US Region")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.barh(df["US Regions"], df["Average Monthly Tax Credit (2016)"], color="lightred")
plt.xlabel("Average Monthly Tax Credit (2016)")
plt.title("The Average Monthly Tax Credit for Each US Region")
plt.show()

# %%
df.pop("US Regions")
df
# Out:
#    Uninsured Rate (2015) Average  Average Monthly Tax Credit (2016)  \
# 0                       0.098308                             312.69
# 1                       0.111357                             313.07
# 2                       0.074667                             270.67
# 3                       0.059636                             261.27
#
#    Employer Health Insurance Coverage (2015) Percentage  \
# 0                                           0.523572
# 1                                           0.497540
# 2                                           0.579352
# 3                                           0.585284
#
#    Medicaid Enrollment (2016) Percentage
# 0                               0.225732
# 1                               0.220678
# 2                               0.184631
# 3                               0.244918

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
pd.plotting.scatter_matrix(df, figsize=(20, 16), diagonal="kde", alpha=0.7)
plt.suptitle("Scatter Matrix of Features", fontsize=16)
plt.show()
